# %% [markdown]
# <a href="https://colab.research.google.com/github/anikkkkdas/Python-Projects/blob/main/1_Intro_to_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Introduction to Functions

print("Hello World")
var = 1000
print(var)
print(10,20,30)

## these are called Built-In_Functions
# Out:
# Hello World
# 1000
# 10 20 30
